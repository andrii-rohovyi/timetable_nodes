# %%
import pandas as pd
import datetime
import numpy as np
from copy import deepcopy
import cProfile
import sys
from collections import defaultdict
from tqdm import tqdm 
import pickle
from bisect import bisect_left
import random
from tqdm import tqdm
import random
import os
import logging


from data_structures.graph import TransportGraph, ContactionTransportGraph
from algorithms.forward_search import FCH
from algorithms.dijkstra import Dijkstra
from data_structures.timetable import Timetable
from algorithms.connection_scan_algorithm import ConnectionScanAlgorithm

# %% [markdown]
# # Select city

# %%
CITY = 'luxembourg'

# %% [markdown]
# # Build Transport Graphs

# %%
# Download transport connection
transport_connections = pd.read_csv(F'data/{CITY}/network_temporal_day.csv', sep=';')
transport_connections = transport_connections[
    transport_connections['from_stop_I']!=transport_connections['to_stop_I']]

# Download walking connections
walk_connections = pd.read_csv(F'data/{CITY}/network_walk.csv', sep=';')
df_walk_invert = walk_connections.copy()
df_walk_invert = df_walk_invert.rename(columns={'from_stop_I': 'to_stop_I', 'to_stop_I': 'from_stop_I'})
walk_connections = pd.concat((walk_connections, df_walk_invert))

#Additional limit 
walk_connections = walk_connections[walk_connections['d_walk'] < 600]

#Build tg graph
tg = TransportGraph(transport_connections=transport_connections, walk_connections=walk_connections)

# %%
NODES = tg.nodes

# %% [markdown]
# # Build CH-graph

# %%
ch_tg = tg.contraction_hierarchy()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:26<00:00, 51.48it/s]

# %% [markdown]
# # Precompute geometrical containers

# %%
ch_tg.geometrical_container()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 14436.57it/s]

# %% [markdown]
# # Precompute timetable nodes

# %% [markdown]
# ### For standard graph

# %%
tg_ttn = deepcopy(tg)
tg_ttn_fc_ascending = deepcopy(tg)
tg_ttn_fc_descending = deepcopy(tg)

tg_ttn.optimize_binary_search()

tg_ttn_fc_ascending.fractional_cascading_precomputation('ascending')
tg_ttn_fc_descending.fractional_cascading_precomputation('descending')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 2446.51it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 3810.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 3563.96it/s]

# %% [markdown]
# ### For CH-graph

# %%
ch_tg_ttn = deepcopy(ch_tg)
ch_tg_ttn_fc_ascending = deepcopy(ch_tg)
ch_tg_ttn_fc_descending = deepcopy(ch_tg)
ch_tg_ttn_fc_hierarchy = deepcopy(ch_tg)

ch_tg_ttn.optimize_binary_search()
ch_tg_ttn_fc_ascending.fractional_cascading_precomputation('ascending')
ch_tg_ttn_fc_descending.fractional_cascading_precomputation('descending')
ch_tg_ttn_fc_hierarchy.fractional_cascading_precomputation('contraction_hierarchy')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:07<00:00, 185.25it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:02<00:00, 532.57it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:02<00:00, 523.36it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:09<00:00, 145.33it/s]

# %% [markdown]
# # Prepare data for Connection Scan Algorithm

# %%
timetable = Timetable(transport_connections=transport_connections, walk_connections=walk_connections)

# %% [markdown]
# # Save Preprocessed Data Structures

# %%
# os.mkdir(f'graph/')


# Classic Transport graph
pickle.dump(tg, open(f'graph/{CITY}_tg.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn, open(f'graph/{CITY}_tg_ttn.pkl', 'wb'), 
        pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn_fc_ascending, open(f'graph/{CITY}_tg_ttn_fc_ascending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn_fc_descending, open(f'graph/{CITY}_tg_ttn_fc_descending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# CH-graph
pickle.dump(ch_tg, open(f'graph/{CITY}_ch_tg.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn, open(f'graph/{CITY}_ch_tg_ttn.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_ascending, open(f'graph/{CITY}_ch_tg_ttn_fc_ascending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_descending, open(f'graph/{CITY}_ch_tg_ttn_fc_descending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_hierarchy, open(f'graph/{CITY}_ch_tg_ttn_fc_hierarchy.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# CSA precomputation
pickle.dump(timetable, open(f'graph/{CITY}_csa.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Delete datastructures to reduce memory udage for test

# %%
del tg, tg_ttn, tg_ttn_fc_ascending, tg_ttn_fc_descending, ch_tg, ch_tg_ttn, ch_tg_ttn_fc_ascending, ch_tg_ttn_fc_descending, ch_tg_ttn_fc_hierarchy,timetable

# %% [markdown]
# # Compare solutions

# %%
N = 1000
algorithms = [ 'tg', 'tg_ttn', 'tg_ttn_fc_ascending', 'tg_ttn_fc_descending',
         'ch_tg', 'ch_tg_ttn', 'ch_tg_ttn_fc_ascending', 'ch_tg_ttn_fc_descending', 'ch_tg_ttn_fc_hierarchy',
         'csa']
#results = []


test_data = pd.DataFrame({'start_time': [random.randint(transport_connections['dep_time_ut'].min(), 
                                       transport_connections['dep_time_ut'].max()) for i in range(N)],
         'start_node' : [random.sample(NODES, 1)[0] for i in range(N)], 
          'end_node' : [random.sample(NODES, 1)[0] for i in range(N)]
         })
duration = {x: [] for x in algorithms}
explored_nodes = {x: [] for x in algorithms}
trip_duration = {x: [] for x in algorithms}

for algorithm in algorithms:
    graph = pickle.load(open(F'graph/{CITY}_{algorithm}.pkl', 'rb'))
    for index, row in test_data.iterrows():
        if algorithm == 'ch_tg':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'ch_tg_ttn':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='cst')
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm in ['ch_tg_ttn_fc_ascending', 'ch_tg_ttn_fc_descending']: 
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
            
        elif algorithm == 'ch_tg_ttn_fc_hierarchy':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='fc_chs')
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
            
        elif algorithm == 'tg':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_ttn':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='cst')
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm in ['tg_ttn_fc_ascending', 'tg_ttn_fc_descending']:
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'csa':
            pathfinding = ConnectionScanAlgorithm(graph=graph,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
            
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
# Out:
# /var/folders/kt/g2cs84fs4j3c1psy_vtfg4h40000gn/T/ipykernel_67916/696535104.py:10: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   'start_node' : [random.sample(NODES, 1)[0] for i in range(N)],
# /var/folders/kt/g2cs84fs4j3c1psy_vtfg4h40000gn/T/ipykernel_67916/696535104.py:11: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   'end_node' : [random.sample(NODES, 1)[0] for i in range(N)]
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 753 not reachable from node 1470
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 258 not reachable from node 2431
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 132 not reachable from node 1428
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 2502 not reachable from node 172
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 1784 not reachable from node 238
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 229 not reachable from node 1125
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 601 not reachable from node 671
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 71 not reachable from node 218
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 2440 not reachable from node 380
# WARNING:root:Target 1757 not reachable from node 740
# WARNING:root:Target 1154 not reachable from node 2415
# WARNING:root:Target 1715 not reachable from node 2002
# WARNING:root:Target 753 not reachable from node 1470
# WARNING:root:Target 545 not reachable from node 1137
# WARNING:root:Target 765 not reachable from node 2098
# WARNING:root:Target 1769 not reachable from node 2491
# WARNING:root:Target 183 not reachable from node 1458
# WARNING:root:Target 266 not reachable from node 31
# WARNING:root:Target 288 not reachable from node 2106
# WARNING:root:Target 1688 not reachable from node 785
# WARNING:root:Target 596 not reachable from node 1031
# WARNING:root:Target 84 not reachable from node 2495
# WARNING:root:Target 1617 not reachable from node 1886
# WARNING:root:Target 1243 not reachable from node 2548
# WARNING:root:Target 1807 not reachable from node 1166
# WARNING:root:Target 1330 not reachable from node 917
# WARNING:root:Target 1884 not reachable from node 1419
# WARNING:root:Target 2345 not reachable from node 111
# WARNING:root:Target 522 not reachable from node 1856
# WARNING:root:Target 1510 not reachable from node 1806
# WARNING:root:Target 1830 not reachable from node 2455
# WARNING:root:Target 174 not reachable from node 775
# WARNING:root:Target 1727 not reachable from node 1037
# WARNING:root:Target 2439 not reachable from node 1431
# WARNING:root:Target 1487 not reachable from node 976
# WARNING:root:Target 1926 not reachable from node 1817
# WARNING:root:Target 1403 not reachable from node 1398
# WARNING:root:Target 282 not reachable from node 1263
# WARNING:root:Target 2548 not reachable from node 1994
# WARNING:root:Target 460 not reachable from node 2460
# WARNING:root:Target 1126 not reachable from node 340
# WARNING:root:Target 1356 not reachable from node 1617
# WARNING:root:Target 585 not reachable from node 417
# WARNING:root:Target 367 not reachable from node 2302
# WARNING:root:Target 2044 not reachable from node 2259
# WARNING:root:Target 1728 not reachable from node 696
# WARNING:root:Target 387 not reachable from node 67
# WARNING:root:Target 1956 not reachable from node 99
# WARNING:root:Target 1055 not reachable from node 1833
# WARNING:root:Target 813 not reachable from node 2277
# WARNING:root:Target 1087 not reachable from node 459
# WARNING:root:Target 2186 not reachable from node 953
# WARNING:root:Target 271 not reachable from node 1746
# WARNING:root:Target 1617 not reachable from node 612
# WARNING:root:Target 1714 not reachable from node 1649
# WARNING:root:Target 1185 not reachable from node 1997
# WARNING:root:Target 292 not reachable from node 1002
# WARNING:root:Target 2269 not reachable from node 1438
# WARNING:root:Target 1384 not reachable from node 1764
# WARNING:root:Target 2077 not reachable from node 750
# WARNING:root:Target 1644 not reachable from node 1170
# WARNING:root:Target 1756 not reachable from node 1479
# WARNING:root:Target 1886 not reachable from node 920
# WARNING:root:Target 2418 not reachable from node 2342
# WARNING:root:Target 215 not reachable from node 838
# WARNING:root:Target 1771 not reachable from node 261
# WARNING:root:Target 2305 not reachable from node 263
# WARNING:root:Target 2186 not reachable from node 1701
# WARNING:root:Target 792 not reachable from node 2118
# WARNING:root:Target 562 not reachable from node 1420
# WARNING:root:Target 1265 not reachable from node 2093
# WARNING:root:Target 1899 not reachable from node 1353
# WARNING:root:Target 1942 not reachable from node 535
# WARNING:root:Target 2325 not reachable from node 1004
# WARNING:root:Target 2480 not reachable from node 2501
# WARNING:root:Target 1619 not reachable from node 1727
# WARNING:root:Target 2480 not reachable from node 185
# WARNING:root:Target 1336 not reachable from node 925
# WARNING:root:Target 2470 not reachable from node 2436
# WARNING:root:Target 1327 not reachable from node 494
# WARNING:root:Target 132 not reachable from node 1428
# WARNING:root:Target 2312 not reachable from node 645
# WARNING:root:Target 1213 not reachable from node 1790
# WARNING:root:Target 395 not reachable from node 1388
# WARNING:root:Target 1085 not reachable from node 890
# WARNING:root:Target 1006 not reachable from node 262
# WARNING:root:Target 983 not reachable from node 2435
# WARNING:root:Target 2352 not reachable from node 2350
# WARNING:root:Target 202 not reachable from node 1578
# WARNING:root:Target 1645 not reachable from node 1987
# WARNING:root:Target 999 not reachable from node 1998
# WARNING:root:Target 1953 not reachable from node 2077
# WARNING:root:Target 1698 not reachable from node 1902
# WARNING:root:Target 2346 not reachable from node 288
# WARNING:root:Target 2330 not reachable from node 314
# WARNING:root:Target 781 not reachable from node 735
# WARNING:root:Target 2163 not reachable from node 1230
# WARNING:root:Target 2151 not reachable from node 2259
# WARNING:root:Target 331 not reachable from node 1008
# WARNING:root:Target 901 not reachable from node 265
# WARNING:root:Target 53 not reachable from node 1673
# WARNING:root:Target 1696 not reachable from node 2231
# WARNING:root:Target 1757 not reachable from node 1419
# WARNING:root:Target 434 not reachable from node 515
# WARNING:root:Target 225 not reachable from node 880
# WARNING:root:Target 679 not reachable from node 1437
# WARNING:root:Target 1527 not reachable from node 1644
# WARNING:root:Target 478 not reachable from node 63
# WARNING:root:Target 1771 not reachable from node 123
# WARNING:root:Target 1523 not reachable from node 457
# WARNING:root:Target 1126 not reachable from node 1902
# WARNING:root:Target 2316 not reachable from node 31
# WARNING:root:Target 1789 not reachable from node 1281
# WARNING:root:Target 1619 not reachable from node 1551
# WARNING:root:Target 563 not reachable from node 1498
# WARNING:root:Target 292 not reachable from node 456
# WARNING:root:Target 1659 not reachable from node 1247
# WARNING:root:Target 1281 not reachable from node 810
# WARNING:root:Target 438 not reachable from node 214
# WARNING:root:Target 1290 not reachable from node 164
# WARNING:root:Target 1392 not reachable from node 945
# WARNING:root:Target 1918 not reachable from node 1416
# WARNING:root:Target 227 not reachable from node 2118
# WARNING:root:Target 719 not reachable from node 530
# WARNING:root:Target 645 not reachable from node 761
# WARNING:root:Target 1175 not reachable from node 98
# WARNING:root:Target 71 not reachable from node 218
# WARNING:root:Target 1622 not reachable from node 2096
# WARNING:root:Target 747 not reachable from node 2096
# WARNING:root:Target 1572 not reachable from node 708
# WARNING:root:Target 530 not reachable from node 1163
# WARNING:root:Target 1746 not reachable from node 440
# WARNING:root:Target 1613 not reachable from node 976
# WARNING:root:Target 1194 not reachable from node 341
# WARNING:root:Target 2364 not reachable from node 1316
# WARNING:root:Target 2087 not reachable from node 1591
# WARNING:root:Target 1561 not reachable from node 1420
# WARNING:root:Target 1509 not reachable from node 1426
# WARNING:root:Target 1247 not reachable from node 1264
# WARNING:root:Target 495 not reachable from node 1736
# WARNING:root:Target 1867 not reachable from node 1547
# WARNING:root:Target 1757 not reachable from node 740

# %% [markdown]
# # Results

# %%
for algorithm in algorithms:
    print(algorithm, np.mean(duration[algorithm]), np.std(duration[algorithm]))
# Out:
# tg 7.775 4.9534205353472665
# tg_ttn 7.094 4.6285163929708615
# tg_ttn_fc_ascending 6.925 4.525635314516626
# tg_ttn_fc_descending 7.518 5.072245656511522
# ch_tg 4.343 2.3641808306472663
# ch_tg_ttn 2.471 1.5255028679094642
# ch_tg_ttn_fc_ascending 3.871 2.133625787245739
# ch_tg_ttn_fc_descending 3.908 2.145585234848525
# ch_tg_ttn_fc_hierarchy 3.316 1.9626879527831211
# csa 5.404 4.164706952475768
