# %%
import pandas as pd
import datetime
import numpy as np
from copy import deepcopy
import cProfile
import sys
from collections import defaultdict
from tqdm import tqdm 
import pickle
from bisect import bisect_left
import random
from tqdm import tqdm
import random
import os
import logging


from graph import TransportGraph, ContactionTransportGraph
from forward_search import FCH
from dijkstra import Dijkstra
from timetable import Timetable
from connection_scan_algorithm import ConnectionScanAlgorithm

# %% [markdown]
# # Select city

# %%
CITY = 'luxembourg'

# %% [markdown]
# # Build Transport Graphs

# %%
# Download transport connection
transport_connections = pd.read_csv(F'data/{CITY}/network_temporal_day.csv', sep=';')
transport_connections = transport_connections[
    transport_connections['from_stop_I']!=transport_connections['to_stop_I']]

# Download walking connections
walk_connections = pd.read_csv(F'data/{CITY}/network_walk.csv', sep=';')
df_walk_invert = walk_connections.copy()
df_walk_invert = df_walk_invert.rename(columns={'from_stop_I': 'to_stop_I', 'to_stop_I': 'from_stop_I'})
walk_connections = pd.concat((walk_connections, df_walk_invert))

#Additional limit 
walk_connections = walk_connections[walk_connections['d_walk'] < 600]

#Build tg graph
tg = TransportGraph(transport_connections=transport_connections, walk_connections=walk_connections)

# %%
NODES = tg.nodes

# %% [markdown]
# # Build CH-graph

# %%
ch_tg = tg.contraction_hierarchy()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:29<00:00, 47.06it/s]

# %% [markdown]
# # Precompute geometrical containers

# %%
ch_tg.geometrical_container()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 14065.97it/s]

# %% [markdown]
# # Precompute timetable nodes

# %% [markdown]
# ### For standard graph

# %%
tg_ttn = deepcopy(tg)
tg_ttn_fc_ascending = deepcopy(tg)
tg_ttn_fc_descending = deepcopy(tg)

tg_ttn.optimize_binary_search()

tg_ttn_fc_ascending.fractional_cascading_precomputation('ascending')
tg_ttn_fc_descending.fractional_cascading_precomputation('descending')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 2362.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 3548.35it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:00<00:00, 3329.01it/s]

# %% [markdown]
# ### For CH-graph

# %%
ch_tg_ttn = deepcopy(ch_tg)
ch_tg_ttn_fc_ascending = deepcopy(ch_tg)
ch_tg_ttn_fc_descending = deepcopy(ch_tg)
ch_tg_ttn_fc_hierarchy = deepcopy(ch_tg)

ch_tg_ttn.optimize_binary_search()
ch_tg_ttn_fc_ascending.fractional_cascading_precomputation('ascending')
ch_tg_ttn_fc_descending.fractional_cascading_precomputation('descending')
ch_tg_ttn_fc_hierarchy.fractional_cascading_precomputation('contraction_hierarchy')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:07<00:00, 181.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:02<00:00, 518.60it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:09<00:00, 136.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1367/1367 [00:02<00:00, 494.74it/s]

# %% [markdown]
# # Prepare data for Connection Scan Algorithm

# %%
timetable = Timetable(transport_connections=transport_connections, walk_connections=walk_connections)

# %% [markdown]
# # Save Preprocessed Data Structures

# %%
# os.mkdir(f'graph/')


# Classic Transport graph
pickle.dump(tg, open(f'graph/{CITY}_tg.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn, open(f'graph/{CITY}_tg_ttn.pkl', 'wb'), 
        pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn_fc_ascending, open(f'graph/{CITY}_tg_ttn_fc_ascending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(tg_ttn_fc_descending, open(f'graph/{CITY}_tg_ttn_fc_descending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# CH-graph
pickle.dump(ch_tg, open(f'graph/{CITY}_ch_tg.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn, open(f'graph/{CITY}_ch_tg_ttn.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_ascending, open(f'graph/{CITY}_ch_tg_ttn_fc_ascending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_descending, open(f'graph/{CITY}_ch_tg_ttn_fc_descending.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)
pickle.dump(ch_tg_ttn_fc_hierarchy, open(f'graph/{CITY}_ch_tg_ttn_fc_hierarchy.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# CSA precomputation
pickle.dump(timetable, open(f'graph/{CITY}_csa.pkl', 'wb'), 
            pickle.HIGHEST_PROTOCOL)

# %%
del tg, tg_ttn, tg_ttn_fc_ascending, tg_ttn_fc_descending, ch_tg, ch_tg_ttn, ch_tg_ttn_fc_ascending, ch_tg_ttn_fc_descending, ch_tg_ttn_fc_hierarchy,timetable

# %% [markdown]
# # Compare solutions

# %%
N = 1000
algorithms = [ 'tg', 'tg_ttn', 'tg_ttn_fc_ascending', 'tg_ttn_fc_descending',
         'ch_tg', 'ch_tg_ttn', 'ch_tg_ttn_fc_ascending', 'ch_tg_ttn_fc_descending', 'ch_tg_ttn_fc_hierarchy',
         'csa']
#results = []


test_data = pd.DataFrame({'start_time': [random.randint(transport_connections['dep_time_ut'].min(), 
                                       transport_connections['dep_time_ut'].max()) for i in range(N)],
         'start_node' : [random.sample(NODES, 1)[0] for i in range(N)], 
          'end_node' : [random.sample(NODES, 1)[0] for i in range(N)]
         })
duration = {x: [] for x in algorithms}
explored_nodes = {x: [] for x in algorithms}
trip_duration = {x: [] for x in algorithms}

for algorithm in algorithms:
    graph = pickle.load(open(F'graph/{CITY}_{algorithm}.pkl', 'rb'))
    for index, row in test_data.iterrows():
        if algorithm == 'ch_tg':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, optimized_binary_search=False, fractional_cascading=False,
                      fractional_cascading_old=False)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'ch_tg_ttn':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             optimized_binary_search=True, 
                                             fractional_cascading=False,
                                             fractional_cascading_old=False)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'ch_tg_ttn_fc_ascending': 
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             optimized_binary_search=True, 
                                             fractional_cascading=False,
                                             fractional_cascading_old=True)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'ch_tg_ttn_fc_descending':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             optimized_binary_search=True, 
                                             fractional_cascading=False,
                                             fractional_cascading_old=True)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
            
        elif algorithm == 'ch_tg_ttn_fc_hierarchy':
            pathfinding = FCH(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, 
                                             optimized_binary_search=True, 
                                             fractional_cascading=True,
                                             fractional_cascading_old=False)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
            
        elif algorithm == 'tg':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, optimized_binary_search=False, fractional_cascading=False)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_ttn':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, optimized_binary_search=True, fractional_cascading=False)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm =='tg_ttn_fc_ascending':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, optimized_binary_search=True, fractional_cascading=True)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_ttn_fc_descending':
            pathfinding = Dijkstra(graph=graph,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'])
            path = pathfinding.shortest_path(60, optimized_binary_search=True, fractional_cascading=True)
            duration[algorithm].append(path['duration'])
            explored_nodes[algorithm].append(len(pathfinding.candidate_weights))
            
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'csa':
            pathfinding = ConnectionScanAlgorithm(graph=graph,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
            
            if path['path']:
                trip_duration[algorithm].append(path['arrival'] - row['start_time'])
# Out:
# /var/folders/kt/g2cs84fs4j3c1psy_vtfg4h40000gn/T/ipykernel_62497/3755359733.py:10: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   'start_node' : [random.sample(NODES, 1)[0] for i in range(N)],
# /var/folders/kt/g2cs84fs4j3c1psy_vtfg4h40000gn/T/ipykernel_62497/3755359733.py:11: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   'end_node' : [random.sample(NODES, 1)[0] for i in range(N)]
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337
# WARNING:root:Target 1841 not reachable from node 1994
# WARNING:root:Target 2270 not reachable from node 2298
# WARNING:root:Target 853 not reachable from node 1325
# WARNING:root:Target 1543 not reachable from node 382
# WARNING:root:Target 751 not reachable from node 282
# WARNING:root:Target 494 not reachable from node 2001
# WARNING:root:Target 361 not reachable from node 220
# WARNING:root:Target 1340 not reachable from node 189
# WARNING:root:Target 741 not reachable from node 1284
# WARNING:root:Target 736 not reachable from node 754
# WARNING:root:Target 899 not reachable from node 1438
# WARNING:root:Target 2216 not reachable from node 721
# WARNING:root:Target 31 not reachable from node 2077
# WARNING:root:Target 204 not reachable from node 794
# WARNING:root:Target 568 not reachable from node 2374
# WARNING:root:Target 750 not reachable from node 29
# WARNING:root:Target 641 not reachable from node 1956
# WARNING:root:Target 349 not reachable from node 1697
# WARNING:root:Target 1247 not reachable from node 2350
# WARNING:root:Target 833 not reachable from node 2288
# WARNING:root:Target 1802 not reachable from node 206
# WARNING:root:Target 803 not reachable from node 292
# WARNING:root:Target 244 not reachable from node 682
# WARNING:root:Target 2472 not reachable from node 1386
# WARNING:root:Target 807 not reachable from node 1113
# WARNING:root:Target 2456 not reachable from node 1751
# WARNING:root:Target 2296 not reachable from node 2161
# WARNING:root:Target 816 not reachable from node 1796
# WARNING:root:Target 201 not reachable from node 1956
# WARNING:root:Target 987 not reachable from node 2097
# WARNING:root:Target 1468 not reachable from node 1219
# WARNING:root:Target 68 not reachable from node 1634
# WARNING:root:Target 761 not reachable from node 765
# WARNING:root:Target 2300 not reachable from node 641
# WARNING:root:Target 1958 not reachable from node 365
# WARNING:root:Target 673 not reachable from node 48
# WARNING:root:Target 1147 not reachable from node 1858
# WARNING:root:Target 1838 not reachable from node 405
# WARNING:root:Target 1208 not reachable from node 719
# WARNING:root:Target 681 not reachable from node 1505
# WARNING:root:Target 2271 not reachable from node 376
# WARNING:root:Target 2459 not reachable from node 1806
# WARNING:root:Target 1781 not reachable from node 1382
# WARNING:root:Target 784 not reachable from node 2266
# WARNING:root:Target 1226 not reachable from node 207
# WARNING:root:Target 2349 not reachable from node 1692
# WARNING:root:Target 1921 not reachable from node 2023
# WARNING:root:Target 1525 not reachable from node 2383
# WARNING:root:Target 2019 not reachable from node 359
# WARNING:root:Target 1726 not reachable from node 1549
# WARNING:root:Target 373 not reachable from node 1070
# WARNING:root:Target 1593 not reachable from node 1688
# WARNING:root:Target 2314 not reachable from node 1436
# WARNING:root:Target 767 not reachable from node 2448
# WARNING:root:Target 2415 not reachable from node 200
# WARNING:root:Target 56 not reachable from node 1673
# WARNING:root:Target 477 not reachable from node 1249
# WARNING:root:Target 1434 not reachable from node 462
# WARNING:root:Target 1166 not reachable from node 1765
# WARNING:root:Target 1796 not reachable from node 2548
# WARNING:root:Target 1415 not reachable from node 1816
# WARNING:root:Target 1142 not reachable from node 1897
# WARNING:root:Target 1715 not reachable from node 1915
# WARNING:root:Target 1858 not reachable from node 2305
# WARNING:root:Target 258 not reachable from node 987
# WARNING:root:Target 1899 not reachable from node 761
# WARNING:root:Target 1932 not reachable from node 1085
# WARNING:root:Target 1264 not reachable from node 1229
# WARNING:root:Target 1667 not reachable from node 2210
# WARNING:root:Target 444 not reachable from node 1181
# WARNING:root:Target 1460 not reachable from node 199
# WARNING:root:Target 1225 not reachable from node 2469
# WARNING:root:Target 629 not reachable from node 234
# WARNING:root:Target 186 not reachable from node 1290
# WARNING:root:Target 2259 not reachable from node 2064
# WARNING:root:Target 981 not reachable from node 2460
# WARNING:root:Target 393 not reachable from node 87
# WARNING:root:Target 1105 not reachable from node 500
# WARNING:root:Target 1994 not reachable from node 104
# WARNING:root:Target 2217 not reachable from node 802
# WARNING:root:Target 775 not reachable from node 1243
# WARNING:root:Target 1084 not reachable from node 829
# WARNING:root:Target 113 not reachable from node 1145
# WARNING:root:Target 53 not reachable from node 1743
# WARNING:root:Target 2462 not reachable from node 1757
# WARNING:root:Target 25 not reachable from node 417
# WARNING:root:Target 1242 not reachable from node 2311
# WARNING:root:Target 765 not reachable from node 265
# WARNING:root:Target 1653 not reachable from node 563
# WARNING:root:Target 1455 not reachable from node 2241
# WARNING:root:Target 60 not reachable from node 1919
# WARNING:root:Target 261 not reachable from node 1030
# WARNING:root:Target 261 not reachable from node 1415
# WARNING:root:Target 1640 not reachable from node 2312
# WARNING:root:Target 246 not reachable from node 1714
# WARNING:root:Target 1759 not reachable from node 405
# WARNING:root:Target 645 not reachable from node 2291
# WARNING:root:Target 272 not reachable from node 2440
# WARNING:root:Target 1206 not reachable from node 67
# WARNING:root:Target 224 not reachable from node 1361
# WARNING:root:Target 803 not reachable from node 2243
# WARNING:root:Target 366 not reachable from node 1642
# WARNING:root:Target 2284 not reachable from node 2243
# WARNING:root:Target 2303 not reachable from node 2234
# WARNING:root:Target 1173 not reachable from node 339
# WARNING:root:Target 752 not reachable from node 2077
# WARNING:root:Target 1789 not reachable from node 570
# WARNING:root:Target 1465 not reachable from node 807
# WARNING:root:Target 334 not reachable from node 750
# WARNING:root:Target 750 not reachable from node 793
# WARNING:root:Target 98 not reachable from node 1426
# WARNING:root:Target 2300 not reachable from node 1170
# WARNING:root:Target 833 not reachable from node 1240
# WARNING:root:Target 1464 not reachable from node 2294
# WARNING:root:Target 1132 not reachable from node 2311
# WARNING:root:Target 1333 not reachable from node 2228
# WARNING:root:Target 1414 not reachable from node 326
# WARNING:root:Target 1762 not reachable from node 2006
# WARNING:root:Target 1843 not reachable from node 1337

# %% [markdown]
# # Results

# %%
for algorithm in algorithms:
    print(algorithm, np.mean(duration[algorithm]), np.std(duration[algorithm]))
# Out:
# tg 8.879 5.667835477499325
# tg_ttn 7.255 4.772627682943642
# tg_ttn_fc_ascending 7.36 4.888394419438759
# tg_ttn_fc_descending 7.691 10.79877395818618
# ch_tg 4.201 2.1933077759402577
# ch_tg_ttn 2.559 1.3588668073067354
# ch_tg_ttn_fc_ascending 4.093 2.1176286265537683
# ch_tg_ttn_fc_descending 3.879 2.0204848428038256
# ch_tg_ttn_fc_hierarchy 3.433 1.854591868848777
# csa 5.455 4.548403566087776
