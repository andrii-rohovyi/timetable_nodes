# %%
import pandas as pd
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import sys

sys.path.append('../')


from algorithms.dijkstra import CustomizedTimeDependentDijkstra, McCustomizedTimeDependentDijkstra
from algorithms.raptor import CustomizedRAPTOR, McCustomizedRAPTOR

from data_structures.graph import CustomizedTransportGraph
from data_structures.raptor_data_struct import CustomizedRAPTOR_DS
from data_structures.timetable import CustomizedTimetable
from algorithms.connection_scan_algorithm import CustomizedConnectionScanAlgorithm, McCustomizedConnectionScanAlgorithm

# %% [markdown]
# # Select city

# %%
CITY = 'kuopio'

# %% [markdown]
# # Build Transport Graphs

# %%
walk_connections_transitive = pd.read_csv(F'data/{CITY}/walk_connections_transitive.csv')

walk_connections = pd.read_csv(F'data/{CITY}/network_walk.csv', sep=';')
df_walk_invert = walk_connections.copy()
df_walk_invert = df_walk_invert.rename(columns={'from_stop_I': 'to_stop_I', 'to_stop_I': 'from_stop_I'})
walk_connections = pd.concat((walk_connections, df_walk_invert))

transport_connections = pd.read_csv(F'data/{CITY}/network_temporal_day.csv', sep=';')
transport_connections = transport_connections[
    transport_connections['from_stop_I']!=transport_connections['to_stop_I']
].reset_index(drop=True).sort_values(by=['dep_time_ut', 'arr_time_ut'])

# %%
tg = CustomizedTransportGraph(transport_connections=transport_connections, walk_connections=walk_connections)

# %% [markdown]
# # Precompute timetable nodes

# %% [markdown]
# ### For standard graph

# %%
tg_cst = deepcopy(tg)
tg_bst = deepcopy(tg)
tg_ttn_fc_ascending = deepcopy(tg)
tg_ttn_fc_descending = deepcopy(tg)

tg_cst.optimize_binary_search(method='cst')
tg_bst.optimize_binary_search(method='bst')

tg_ttn_fc_ascending.fractional_cascading_precomputation('ascending')
tg_ttn_fc_descending.fractional_cascading_precomputation('descending')
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 548/548 [00:00<00:00, 3425.94it/s]
# 100%|█████████████████████████████████████████████████████████████████| 548/548 [00:00<00:00, 2751.29it/s]
# 100%|████████████████████████████████████████████████████████████████| 548/548 [00:00<00:00, 11722.74it/s]
# 100%|████████████████████████████████████████████████████████████████| 548/548 [00:00<00:00, 11696.38it/s]

# %% [markdown]
# # Prepare data for Raptor

# %%
raptor_ds = CustomizedRAPTOR_DS(transport_connections=transport_connections, walk_connections=walk_connections_transitive)

# %% [markdown]
# # Prepare data for Connection Scan Algorithm

# %%
timetable = CustomizedTimetable(transport_connections=transport_connections, walk_connections=walk_connections_transitive)

# %% [markdown]
# # Compare solutions

# %%
N = 1000
algorithms = [ 'tg', 'tg_bst', 'tg_cst', 'tg_ttn_fc_ascending', 'tg_ttn_fc_descending', 'csa', 'raptor']
results = []


test_data = pd.read_csv(F'graph/{CITY}/{CITY}_test_data.pkl')
        
duration = {x: [] for x in algorithms}
explored_nodes = {x: [] for x in algorithms}
trip_duration = {x: [] for x in algorithms}

for index, row in tqdm(test_data.iterrows(), total=N): 
    for algorithm in algorithms:
        if algorithm == 'tg':
            pathfinding = CustomizedTimeDependentDijkstra(graph=tg,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(60)
            duration[algorithm].append(path['duration'])
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_bst':
            pathfinding = CustomizedTimeDependentDijkstra(graph=tg_bst,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='bst')
            duration[algorithm].append(path['duration'])
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_cst':
            pathfinding = CustomizedTimeDependentDijkstra(graph=tg_cst,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='cst')
            duration[algorithm].append(path['duration'])
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_ttn_fc_ascending':
            pathfinding = CustomizedTimeDependentDijkstra(graph=tg_ttn_fc_ascending,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
            
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'tg_ttn_fc_descending':
            pathfinding = CustomizedTimeDependentDijkstra(graph=tg_ttn_fc_descending,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(60, 
                                             time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
            
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
        elif algorithm == 'csa':
            pathfinding = CustomizedConnectionScanAlgorithm(graph=timetable,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
                
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])

        elif algorithm == 'raptor':
            pathfinding = CustomizedRAPTOR(graph=raptor_ds,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'],
                                           walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
                
            trip_duration[algorithm].append(path['arrival'] - row['start_time'])
# Out:
#   1%|▊                                                                  | 13/1000 [00:01<01:57,  8.40it/s]WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
#   2%|█                                                                  | 16/1000 [00:02<02:08,  7.66it/s]WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
#   3%|██                                                                 | 30/1000 [00:03<01:42,  9.49it/s]WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
#   4%|██▌                                                                | 39/1000 [00:04<02:02,  7.86it/s]WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
#   5%|███                                                                | 46/1000 [00:05<01:55,  8.29it/s]WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
#   5%|███▎                                                               | 50/1000 [00:06<01:46,  8.91it/s]WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
#   5%|███▌                                                               | 53/1000 [00:06<02:08,  7.39it/s]WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
#   8%|█████▌                                                             | 83/1000 [00:10<01:38,  9.29it/s]WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
#  10%|██████▊                                                           | 103/1000 [00:12<01:40,  8.92it/s]WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
#  10%|██████▉                                                           | 105/1000 [00:12<01:48,  8.21it/s]WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
#  11%|███████                                                           | 107/1000 [00:12<01:51,  8.04it/s]WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
#  11%|███████▎                                                          | 110/1000 [00:13<02:11,  6.79it/s]WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
#  12%|████████                                                          | 122/1000 [00:14<01:45,  8.34it/s]WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
#  13%|████████▊                                                         | 134/1000 [00:15<01:31,  9.50it/s]WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
#  14%|█████████                                                         | 138/1000 [00:16<02:06,  6.81it/s]WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
#  16%|██████████▉                                                       | 165/1000 [00:20<02:00,  6.93it/s]WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
#  17%|██████████▉                                                       | 166/1000 [00:20<02:16,  6.11it/s]WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
#  18%|████████████▏                                                     | 184/1000 [00:23<02:01,  6.70it/s]WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
#  19%|████████████▌                                                     | 191/1000 [00:24<01:44,  7.70it/s]WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
#  20%|█████████████▏                                                    | 200/1000 [00:25<01:56,  6.88it/s]WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
#  21%|██████████████                                                    | 213/1000 [00:27<02:00,  6.52it/s]WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
#  23%|███████████████                                                   | 229/1000 [00:28<01:41,  7.62it/s]WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
#  24%|████████████████                                                  | 243/1000 [00:30<01:07, 11.27it/s]WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
ARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# 100%|█████████████████████████████████████████████████████████████████| 1000/1000 [02:03<00:00,  8.07it/s]

# %% [markdown]
# # Results

# %%
for algorithm in algorithms:
    print(algorithm, np.mean(duration[algorithm]), np.std(duration[algorithm]))
# Out:
# tg 6.157 3.9350160101326144
# tg_bst 6.438 9.264888342554377
# tg_cst 5.658 3.6990587992082524
# tg_ttn_fc_ascending 5.512 3.638386455559662
# tg_ttn_fc_descending 5.54 3.6840738320506015
# csa 18.149 13.255896763327632
# raptor 72.189 40.04286801666434

# %% [markdown]
# # Mult criteria search

# %%
N = 1000
algorithms = [ 'tg', 'tg_bst', 'tg_cst', 'tg_ttn_fc_ascending', 'tg_ttn_fc_descending', 'csa', 'raptor']
results = []


test_data = pd.read_csv(F'graph/{CITY}/{CITY}_test_data.pkl')
        
duration = {x: [] for x in algorithms}
explored_nodes = {x: [] for x in algorithms}
trip_duration = {x: [] for x in algorithms}

for index, row in tqdm(test_data.iterrows(), total=N): 
    for algorithm in algorithms:
        if algorithm == 'tg':
            pathfinding = McCustomizedTimeDependentDijkstra(graph=tg,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
        elif algorithm == 'tg_bst':
            pathfinding = McCustomizedTimeDependentDijkstra(graph=tg_bst,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(time_table_nodes='bst')
            duration[algorithm].append(path['duration'])
        elif algorithm == 'tg_cst':
            pathfinding = McCustomizedTimeDependentDijkstra(graph=tg_cst,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(time_table_nodes='cst')
            duration[algorithm].append(path['duration'])
        elif algorithm == 'tg_ttn_fc_ascending':
            pathfinding = McCustomizedTimeDependentDijkstra(graph=tg_ttn_fc_ascending,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
        elif algorithm == 'tg_ttn_fc_descending':
            pathfinding = McCustomizedTimeDependentDijkstra(graph=tg_ttn_fc_descending,
                      start_time=row['start_time'],
                      start_node=row['start_node'], 
                      end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path(time_table_nodes='fc')
            duration[algorithm].append(path['duration'])
        elif algorithm == 'csa':
            pathfinding = McCustomizedConnectionScanAlgorithm(graph=timetable,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'],
                                                          walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
                

        elif algorithm == 'raptor':
            pathfinding = McCustomizedRAPTOR(graph=raptor_ds,
                  start_time=row['start_time'],
                  start_node=row['start_node'], 
                  end_node=row['end_node'],
                                           walking_speed = row['walking_speed'])
            path = pathfinding.shortest_path()
            duration[algorithm].append(path['duration'])
# Out:
#   1%|██▎                                                                                                                                                               | 14/1000 [00:53<1:02:09,  3.78s/it]WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
# WARNING:root:Target 766.0 not reachable from node 464.0
#   2%|██▌                                                                                                                                                               | 16/1000 [01:04<1:13:17,  4.47s/it]WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
# WARNING:root:Target 151.0 not reachable from node 766.0
#   3%|█████                                                                                                                                                               | 31/1000 [01:44<33:10,  2.05s/it]WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
# WARNING:root:Target 759.0 not reachable from node 1056.0
#   4%|██████▍                                                                                                                                                           | 40/1000 [02:19<1:09:14,  4.33s/it]WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
# WARNING:root:Target 1323.0 not reachable from node 139.0
#   5%|███████▌                                                                                                                                                            | 46/1000 [02:38<44:00,  2.77s/it]WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
# WARNING:root:Target 463.0 not reachable from node 762.0
#   5%|████████▎                                                                                                                                                           | 51/1000 [02:53<42:52,  2.71s/it]WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
# WARNING:root:Target 769.0 not reachable from node 103.0
#   5%|████████▋                                                                                                                                                           | 53/1000 [02:57<38:44,  2.46s/it]WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
# WARNING:root:Target 817.0 not reachable from node 421.0
#   8%|█████████████▊                                                                                                                                                      | 84/1000 [04:23<50:35,  3.31s/it]WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
# WARNING:root:Target 257.0 not reachable from node 757.0
#  10%|████████████████▊                                                                                                                                                  | 103/1000 [05:29<50:49,  3.40s/it]WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
# WARNING:root:Target 769.0 not reachable from node 1054.0
#  11%|█████████████████▎                                                                                                                                                 | 106/1000 [05:37<41:36,  2.79s/it]WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
# WARNING:root:Target 766.0 not reachable from node 477.0
#  11%|█████████████████▍                                                                                                                                                 | 107/1000 [05:41<48:21,  3.25s/it]WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
# WARNING:root:Target 767.0 not reachable from node 107.0
#  11%|█████████████████▋                                                                                                                                               | 110/1000 [05:57<1:10:25,  4.75s/it]WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 1130.0 not reachable from node 762.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
# WARNING:root:Target 845.0 not reachable from node 764.0
#  12%|████████████████████                                                                                                                                               | 123/1000 [06:44<54:52,  3.75s/it]WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
# WARNING:root:Target 292.0 not reachable from node 774.0
#  13%|█████████████████████▊                                                                                                                                             | 134/1000 [07:13<48:52,  3.39s/it]WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
# WARNING:root:Target 772.0 not reachable from node 170.0
#  14%|██████████████████████▍                                                                                                                                            | 138/1000 [07:28<58:53,  4.10s/it]WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
# WARNING:root:Target 771.0 not reachable from node 434.0
#  16%|██████████████████████████▉                                                                                                                                        | 165/1000 [08:57<38:53,  2.80s/it]WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
# WARNING:root:Target 758.0 not reachable from node 159.0
#  17%|███████████████████████████                                                                                                                                        | 166/1000 [09:01<45:25,  3.27s/it]WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
# WARNING:root:Target 186.0 not reachable from node 763.0
#  18%|█████████████████████████████▉                                                                                                                                     | 184/1000 [10:02<40:04,  2.95s/it]WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
# WARNING:root:Target 768.0 not reachable from node 36.0
#  19%|███████████████████████████████▏                                                                                                                                   | 191/1000 [10:21<34:42,  2.57s/it]WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
# WARNING:root:Target 772.0 not reachable from node 429.0
#  20%|████████████████████████████████▌                                                                                                                                  | 200/1000 [10:53<43:39,  3.27s/it]WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
# WARNING:root:Target 48.0 not reachable from node 764.0
#  21%|██████████████████████████████████▎                                                                                                                              | 213/1000 [11:38<1:00:06,  4.58s/it]WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
# WARNING:root:Target 384.0 not reachable from node 758.0
#  23%|█████████████████████████████████████▎                                                                                                                             | 229/1000 [12:53<59:56,  4.66s/it]WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
# WARNING:root:Target 1350.0 not reachable from node 817.0
#  24%|███████████████████████████████████████▊                                                                                                                           | 244/1000 [13:40<24:14,  1.92s/it]WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
# WARNING:root:Target 765.0 not reachable from node 273.0
#  27%|██████████████████████████████████████████▉                                                                                                                      | 267/1000 [15:12<1:00:54,  4.99s/it]WARNING:root:Target 766.0 not reachable from node 309.0
# WARNING:root:Target 766.0 not reachable from node 309.0
# WARNING:root:Target 766.0 not reachable from node 309.0
# WARNING:root:Target 766.0 not reachable from node 309.0
# WARNING:root:Target 766.0 not reachable from node 309.0
# WARNING:root:Target 766.0 not reachable from node 309.0
#  27%|███████████████████████████████████████████▋                                                                                                                       | 268/1000 [15:16<57:15,  4.69s/it]WARNING:root:Target 427.0 not reachable from node 764.0
# WARNING:root:Target 427.0 not reachable from node 764.0
# WARNING:root:Target 427.0 not reachable from node 764.0
# WARNING:root:Target 427.0 not reachable from node 764.0
# WARNING:root:Target 427.0 not reachable from node 764.0
# WARNING:root:Target 427.0 not reachable from node 764.0
#  28%|████████████████████████████████████████████▊                                                                                                                   | 280/1000 [23:00<18:17:33, 91.46s/it]WARNING:root:Target 768.0 not reachable from node 79.0
# WARNING:root:Target 768.0 not reachable from node 79.0
# WARNING:root:Target 768.0 not reachable from node 79.0
# WARNING:root:Target 768.0 not reachable from node 79.0
# WARNING:root:Target 768.0 not reachable from node 79.0
# WARNING:root:Target 768.0 not reachable from node 79.0
#  30%|████████████████████████████████████████████████▋                                                                                                                  | 299/1000 [24:12<44:39,  3.82s/it]WARNING:root:Target 765.0 not reachable from node 80.0
# WARNING:root:Target 765.0 not reachable from node 80.0
# WARNING:root:Target 765.0 not reachable from node 80.0
# WARNING:root:Target 765.0 not reachable from node 80.0
# WARNING:root:Target 765.0 not reachable from node 80.0
# WARNING:root:Target 765.0 not reachable from node 80.0
#  31%|██████████████████████████████████████████████████                                                                                                                 | 307/1000 [24:42<42:55,  3.72s/it]WARNING:root:Target 1198.0 not reachable from node 190.0
# WARNING:root:Target 1198.0 not reachable from node 190.0
# WARNING:root:Target 1198.0 not reachable from node 190.0
# WARNING:root:Target 1198.0 not reachable from node 190.0
# WARNING:root:Target 1198.0 not reachable from node 190.0
# WARNING:root:Target 1198.0 not reachable from node 190.0
#  31%|███████████████████████████████████████████████████▏                                                                                                               | 314/1000 [25:10<47:56,  4.19s/it]WARNING:root:Target 122.0 not reachable from node 757.0
# WARNING:root:Target 122.0 not reachable from node 757.0
# WARNING:root:Target 122.0 not reachable from node 757.0
# WARNING:root:Target 122.0 not reachable from node 757.0
# WARNING:root:Target 122.0 not reachable from node 757.0
# WARNING:root:Target 122.0 not reachable from node 757.0
#  32%|████████████████████████████████████████████████████▋                                                                                                              | 323/1000 [25:37<38:07,  3.38s/it]WARNING:root:Target 456.0 not reachable from node 275.0
# WARNING:root:Target 456.0 not reachable from node 275.0
# WARNING:root:Target 456.0 not reachable from node 275.0
# WARNING:root:Target 456.0 not reachable from node 275.0
# WARNING:root:Target 456.0 not reachable from node 275.0
# WARNING:root:Target 456.0 not reachable from node 275.0
#  33%|█████████████████████████████████████████████████████▍                                                                                                             | 328/1000 [25:58<48:03,  4.29s/it]WARNING:root:Target 221.0 not reachable from node 773.0
# WARNING:root:Target 221.0 not reachable from node 773.0
# WARNING:root:Target 221.0 not reachable from node 773.0
# WARNING:root:Target 221.0 not reachable from node 773.0
# WARNING:root:Target 221.0 not reachable from node 773.0
# WARNING:root:Target 221.0 not reachable from node 773.0
#  34%|██████████████████████████████████████████████████████▉                                                                                                            | 337/1000 [26:32<58:41,  5.31s/it]WARNING:root:Target 20.0 not reachable from node 773.0
# WARNING:root:Target 20.0 not reachable from node 773.0
# WARNING:root:Target 20.0 not reachable from node 773.0
# WARNING:root:Target 20.0 not reachable from node 773.0
# WARNING:root:Target 20.0 not reachable from node 773.0
# WARNING:root:Target 20.0 not reachable from node 773.0
#  34%|████████████████████████████████████████████████████████▏                                                                                                          | 345/1000 [26:46<29:28,  2.70s/it]WARNING:root:Target 448.0 not reachable from node 763.0
# WARNING:root:Target 448.0 not reachable from node 763.0
# WARNING:root:Target 448.0 not reachable from node 763.0
# WARNING:root:Target 448.0 not reachable from node 763.0
# WARNING:root:Target 448.0 not reachable from node 763.0
# WARNING:root:Target 448.0 not reachable from node 763.0
#  36%|███████████████████████████████████████████████████████████                                                                                                        | 362/1000 [27:55<54:41,  5.14s/it]WARNING:root:Target 846.0 not reachable from node 765.0
# WARNING:root:Target 846.0 not reachable from node 765.0
# WARNING:root:Target 846.0 not reachable from node 765.0
# WARNING:root:Target 846.0 not reachable from node 765.0
# WARNING:root:Target 846.0 not reachable from node 765.0
# WARNING:root:Target 846.0 not reachable from node 765.0
#  37%|███████████████████████████████████████████████████████████▉                                                                                                       | 368/1000 [28:10<37:42,  3.58s/it]WARNING:root:Target 1052.0 not reachable from node 252.0
# WARNING:root:Target 1052.0 not reachable from node 252.0
# WARNING:root:Target 1052.0 not reachable from node 252.0
# WARNING:root:Target 1052.0 not reachable from node 252.0
# WARNING:root:Target 1052.0 not reachable from node 252.0
# WARNING:root:Target 1052.0 not reachable from node 252.0
#  37%|████████████████████████████████████████████████████████████▋                                                                                                      | 372/1000 [28:27<43:30,  4.16s/it]WARNING:root:Target 1223.0 not reachable from node 255.0
# WARNING:root:Target 1223.0 not reachable from node 255.0
# WARNING:root:Target 1223.0 not reachable from node 255.0
# WARNING:root:Target 1223.0 not reachable from node 255.0
# WARNING:root:Target 1223.0 not reachable from node 255.0
# WARNING:root:Target 1223.0 not reachable from node 255.0
#  42%|████████████████████████████████████████████████████████████████████▍                                                                                              | 420/1000 [31:43<37:16,  3.86s/it]WARNING:root:Target 764.0 not reachable from node 310.0
# WARNING:root:Target 764.0 not reachable from node 310.0
# WARNING:root:Target 764.0 not reachable from node 310.0
# WARNING:root:Target 764.0 not reachable from node 310.0
# WARNING:root:Target 764.0 not reachable from node 310.0
# WARNING:root:Target 764.0 not reachable from node 310.0
#  43%|█████████████████████████████████████████████████████████████████████▊                                                                                             | 428/1000 [32:14<30:51,  3.24s/it]WARNING:root:Target 9.0 not reachable from node 766.0
# WARNING:root:Target 9.0 not reachable from node 766.0
# WARNING:root:Target 9.0 not reachable from node 766.0
# WARNING:root:Target 9.0 not reachable from node 766.0
# WARNING:root:Target 9.0 not reachable from node 766.0
# WARNING:root:Target 9.0 not reachable from node 766.0
#  43%|██████████████████████████████████████████████████████████████████████▋                                                                                            | 434/1000 [32:39<33:27,  3.55s/it]WARNING:root:Target 760.0 not reachable from node 74.0
# WARNING:root:Target 760.0 not reachable from node 74.0
# WARNING:root:Target 760.0 not reachable from node 74.0
# WARNING:root:Target 760.0 not reachable from node 74.0
# WARNING:root:Target 760.0 not reachable from node 74.0
# WARNING:root:Target 760.0 not reachable from node 74.0
#  48%|█████████████████████████████████████████████████████████████████████████████▉                                                                                     | 478/1000 [35:12<36:21,  4.18s/it]WARNING:root:Target 37.0 not reachable from node 759.0
# WARNING:root:Target 37.0 not reachable from node 759.0
# WARNING:root:Target 37.0 not reachable from node 759.0
# WARNING:root:Target 37.0 not reachable from node 759.0
# WARNING:root:Target 37.0 not reachable from node 759.0
# WARNING:root:Target 37.0 not reachable from node 759.0
#  49%|███████████████████████████████████████████████████████████████████████████████▌                                                                                   | 488/1000 [35:46<34:14,  4.01s/it]WARNING:root:Target 185.0 not reachable from node 772.0
# WARNING:root:Target 185.0 not reachable from node 772.0
# WARNING:root:Target 185.0 not reachable from node 772.0
# WARNING:root:Target 185.0 not reachable from node 772.0
# WARNING:root:Target 185.0 not reachable from node 772.0
# WARNING:root:Target 185.0 not reachable from node 772.0
#  49%|████████████████████████████████████████████████████████████████████████████████▌                                                                                  | 494/1000 [36:04<29:32,  3.50s/it]WARNING:root:Target 410.0 not reachable from node 757.0
# WARNING:root:Target 410.0 not reachable from node 757.0
# WARNING:root:Target 410.0 not reachable from node 757.0
# WARNING:root:Target 410.0 not reachable from node 757.0
# WARNING:root:Target 410.0 not reachable from node 757.0
# WARNING:root:Target 410.0 not reachable from node 757.0
#  51%|██████████████████████████████████████████████████████████████████████████████████▍                                                                                | 506/1000 [36:37<18:04,  2.20s/it]WARNING:root:Target 440.0 not reachable from node 765.0
# WARNING:root:Target 440.0 not reachable from node 765.0
# WARNING:root:Target 440.0 not reachable from node 765.0
# WARNING:root:Target 440.0 not reachable from node 765.0
# WARNING:root:Target 440.0 not reachable from node 765.0
# WARNING:root:Target 440.0 not reachable from node 765.0
#  53%|█████████████████████████████████████████████████████████████████████████████████████▋                                                                             | 526/1000 [37:50<23:14,  2.94s/it]WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1334.0 not reachable from node 1056.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
# WARNING:root:Target 1133.0 not reachable from node 764.0
#  54%|███████████████████████████████████████████████████████████████████████████████████████▊                                                                           | 539/1000 [38:22<27:18,  3.55s/it]WARNING:root:Target 756.0 not reachable from node 268.0
# WARNING:root:Target 756.0 not reachable from node 268.0
# WARNING:root:Target 756.0 not reachable from node 268.0
# WARNING:root:Target 756.0 not reachable from node 268.0
# WARNING:root:Target 756.0 not reachable from node 268.0
# WARNING:root:Target 756.0 not reachable from node 268.0
#  55%|█████████████████████████████████████████████████████████████████████████████████████████▎                                                                         | 548/1000 [38:49<25:55,  3.44s/it]WARNING:root:Target 764.0 not reachable from node 1320.0
# WARNING:root:Target 764.0 not reachable from node 1320.0
# WARNING:root:Target 764.0 not reachable from node 1320.0
# WARNING:root:Target 764.0 not reachable from node 1320.0
# WARNING:root:Target 764.0 not reachable from node 1320.0
# WARNING:root:Target 764.0 not reachable from node 1320.0
#  56%|███████████████████████████████████████████████████████████████████████████████████████████▉                                                                       | 564/1000 [40:20<33:17,  4.58s/it]WARNING:root:Target 762.0 not reachable from node 258.0
# WARNING:root:Target 762.0 not reachable from node 258.0
# WARNING:root:Target 762.0 not reachable from node 258.0
# WARNING:root:Target 762.0 not reachable from node 258.0
# WARNING:root:Target 762.0 not reachable from node 258.0
# WARNING:root:Target 762.0 not reachable from node 258.0
#  58%|██████████████████████████████████████████████████████████████████████████████████████████████▊                                                                    | 582/1000 [41:31<36:09,  5.19s/it]WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 431.0 not reachable from node 1052.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
# WARNING:root:Target 1223.0 not reachable from node 850.0
#  59%|████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                  | 593/1000 [42:20<44:54,  6.62s/it]WARNING:root:Target 162.0 not reachable from node 773.0
# WARNING:root:Target 162.0 not reachable from node 773.0
# WARNING:root:Target 162.0 not reachable from node 773.0
# WARNING:root:Target 162.0 not reachable from node 773.0
# WARNING:root:Target 162.0 not reachable from node 773.0
# WARNING:root:Target 162.0 not reachable from node 773.0
#  60%|██████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                | 602/1000 [42:51<26:30,  4.00s/it]WARNING:root:Target 758.0 not reachable from node 58.0
# WARNING:root:Target 758.0 not reachable from node 58.0
# WARNING:root:Target 758.0 not reachable from node 58.0
# WARNING:root:Target 758.0 not reachable from node 58.0
# WARNING:root:Target 758.0 not reachable from node 58.0
# WARNING:root:Target 758.0 not reachable from node 58.0
#  60%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                | 605/1000 [43:02<24:10,  3.67s/it]WARNING:root:Target 817.0 not reachable from node 1354.0
# WARNING:root:Target 817.0 not reachable from node 1354.0
# WARNING:root:Target 817.0 not reachable from node 1354.0
# WARNING:root:Target 817.0 not reachable from node 1354.0
# WARNING:root:Target 817.0 not reachable from node 1354.0
# WARNING:root:Target 817.0 not reachable from node 1354.0
#  61%|███████████████████████████████████████████████████████████████████████████████████████████████████                                                                | 608/1000 [43:13<24:21,  3.73s/it]WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 38.0 not reachable from node 763.0
# WARNING:root:Target 415.0 not reachable from node 770.0
# WARNING:root:Target 415.0 not reachable from node 770.0
# WARNING:root:Target 415.0 not reachable from node 770.0
# WARNING:root:Target 415.0 not reachable from node 770.0
# WARNING:root:Target 415.0 not reachable from node 770.0
# WARNING:root:Target 415.0 not reachable from node 770.0
#  62%|████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                              | 615/1000 [43:29<17:13,  2.68s/it]WARNING:root:Target 329.0 not reachable from node 763.0
# WARNING:root:Target 329.0 not reachable from node 763.0
# WARNING:root:Target 329.0 not reachable from node 763.0
# WARNING:root:Target 329.0 not reachable from node 763.0
# WARNING:root:Target 329.0 not reachable from node 763.0
# WARNING:root:Target 329.0 not reachable from node 763.0
#  62%|████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                              | 617/1000 [43:29<10:34,  1.66s/it]WARNING:root:Target 345.0 not reachable from node 775.0
# WARNING:root:Target 345.0 not reachable from node 775.0
# WARNING:root:Target 345.0 not reachable from node 775.0
# WARNING:root:Target 345.0 not reachable from node 775.0
# WARNING:root:Target 345.0 not reachable from node 775.0
# WARNING:root:Target 345.0 not reachable from node 775.0
#  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                            | 630/1000 [44:21<27:40,  4.49s/it]WARNING:root:Target 768.0 not reachable from node 228.0
# WARNING:root:Target 768.0 not reachable from node 228.0
# WARNING:root:Target 768.0 not reachable from node 228.0
# WARNING:root:Target 768.0 not reachable from node 228.0
# WARNING:root:Target 768.0 not reachable from node 228.0
# WARNING:root:Target 768.0 not reachable from node 228.0
#  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                            | 631/1000 [44:23<23:57,  3.90s/it]WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
# WARNING:root:Target 1055.0 not reachable from node 229.0
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                          | 643/1000 [45:00<19:39,  3.31s/it]WARNING:root:Target 767.0 not reachable from node 380.0
# WARNING:root:Target 767.0 not reachable from node 380.0
# WARNING:root:Target 767.0 not reachable from node 380.0
# WARNING:root:Target 767.0 not reachable from node 380.0
# WARNING:root:Target 767.0 not reachable from node 380.0
# WARNING:root:Target 767.0 not reachable from node 380.0
#  65%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                        | 654/1000 [45:36<15:14,  2.64s/it]WARNING:root:Target 761.0 not reachable from node 411.0
# WARNING:root:Target 761.0 not reachable from node 411.0
# WARNING:root:Target 761.0 not reachable from node 411.0
# WARNING:root:Target 761.0 not reachable from node 411.0
# WARNING:root:Target 761.0 not reachable from node 411.0
# WARNING:root:Target 761.0 not reachable from node 411.0
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                       | 661/1000 [46:04<23:50,  4.22s/it]WARNING:root:Target 464.0 not reachable from node 764.0
# WARNING:root:Target 464.0 not reachable from node 764.0
# WARNING:root:Target 464.0 not reachable from node 764.0
# WARNING:root:Target 464.0 not reachable from node 764.0
# WARNING:root:Target 464.0 not reachable from node 764.0
# WARNING:root:Target 464.0 not reachable from node 764.0
#  68%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                    | 676/1000 [46:56<17:17,  3.20s/it]WARNING:root:Target 299.0 not reachable from node 763.0
# WARNING:root:Target 299.0 not reachable from node 763.0
# WARNING:root:Target 299.0 not reachable from node 763.0
# WARNING:root:Target 299.0 not reachable from node 763.0
# WARNING:root:Target 299.0 not reachable from node 763.0
# WARNING:root:Target 299.0 not reachable from node 763.0
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                   | 683/1000 [47:15<14:09,  2.68s/it]WARNING:root:Target 274.0 not reachable from node 762.0
# WARNING:root:Target 274.0 not reachable from node 762.0
# WARNING:root:Target 274.0 not reachable from node 762.0
# WARNING:root:Target 274.0 not reachable from node 762.0
# WARNING:root:Target 274.0 not reachable from node 762.0
# WARNING:root:Target 274.0 not reachable from node 762.0
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                   | 685/1000 [47:16<09:25,  1.80s/it]WARNING:root:Target 764.0 not reachable from node 127.0
# WARNING:root:Target 764.0 not reachable from node 127.0
# WARNING:root:Target 764.0 not reachable from node 127.0
# WARNING:root:Target 764.0 not reachable from node 127.0
# WARNING:root:Target 764.0 not reachable from node 127.0
# WARNING:root:Target 764.0 not reachable from node 127.0
#  69%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                  | 688/1000 [47:31<17:59,  3.46s/it]WARNING:root:Target 281.0 not reachable from node 770.0
# WARNING:root:Target 281.0 not reachable from node 770.0
# WARNING:root:Target 281.0 not reachable from node 770.0
# WARNING:root:Target 281.0 not reachable from node 770.0
# WARNING:root:Target 281.0 not reachable from node 770.0
# WARNING:root:Target 281.0 not reachable from node 770.0
#  70%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 700/1000 [48:08<16:08,  3.23s/it]WARNING:root:Target 765.0 not reachable from node 298.0
# WARNING:root:Target 765.0 not reachable from node 298.0
# WARNING:root:Target 765.0 not reachable from node 298.0
# WARNING:root:Target 765.0 not reachable from node 298.0
# WARNING:root:Target 765.0 not reachable from node 298.0
# WARNING:root:Target 765.0 not reachable from node 298.0
#  72%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                              | 715/1000 [48:58<12:09,  2.56s/it]WARNING:root:Target 289.0 not reachable from node 773.0
# WARNING:root:Target 289.0 not reachable from node 773.0
# WARNING:root:Target 289.0 not reachable from node 773.0
# WARNING:root:Target 289.0 not reachable from node 773.0
# WARNING:root:Target 289.0 not reachable from node 773.0
# WARNING:root:Target 289.0 not reachable from node 773.0
#  73%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                            | 729/1000 [49:37<14:51,  3.29s/it]WARNING:root:Target 768.0 not reachable from node 319.0
# WARNING:root:Target 768.0 not reachable from node 319.0
# WARNING:root:Target 768.0 not reachable from node 319.0
# WARNING:root:Target 768.0 not reachable from node 319.0
# WARNING:root:Target 768.0 not reachable from node 319.0
# WARNING:root:Target 768.0 not reachable from node 319.0
#  74%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                         | 739/1000 [1:02:49<16:40:13, 229.94s/it]WARNING:root:Target 1051.0 not reachable from node 355.0
# WARNING:root:Target 1051.0 not reachable from node 355.0
# WARNING:root:Target 1051.0 not reachable from node 355.0
# WARNING:root:Target 1051.0 not reachable from node 355.0
# WARNING:root:Target 1051.0 not reachable from node 355.0
# WARNING:root:Target 1051.0 not reachable from node 355.0
#  74%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                        | 740/1000 [1:02:51<11:38:55, 161.29s/it]WARNING:root:Target 280.0 not reachable from node 756.0
# WARNING:root:Target 280.0 not reachable from node 756.0
# WARNING:root:Target 280.0 not reachable from node 756.0
# WARNING:root:Target 280.0 not reachable from node 756.0
# WARNING:root:Target 280.0 not reachable from node 756.0
# WARNING:root:Target 280.0 not reachable from node 756.0
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                        | 743/1000 [1:03:00<4:48:23, 67.33s/it]WARNING:root:Target 352.0 not reachable from node 762.0
# WARNING:root:Target 352.0 not reachable from node 762.0
# WARNING:root:Target 352.0 not reachable from node 762.0
# WARNING:root:Target 352.0 not reachable from node 762.0
# WARNING:root:Target 352.0 not reachable from node 762.0
# WARNING:root:Target 352.0 not reachable from node 762.0
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                        | 751/1000 [1:03:24<35:13,  8.49s/it]WARNING:root:Target 96.0 not reachable from node 769.0
# WARNING:root:Target 96.0 not reachable from node 769.0
# WARNING:root:Target 96.0 not reachable from node 769.0
# WARNING:root:Target 96.0 not reachable from node 769.0
# WARNING:root:Target 96.0 not reachable from node 769.0
# WARNING:root:Target 96.0 not reachable from node 769.0
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                 | 791/1000 [1:05:49<12:40,  3.64s/it]WARNING:root:Target 22.0 not reachable from node 770.0
# WARNING:root:Target 22.0 not reachable from node 770.0
# WARNING:root:Target 22.0 not reachable from node 770.0
# WARNING:root:Target 22.0 not reachable from node 770.0
# WARNING:root:Target 22.0 not reachable from node 770.0
# WARNING:root:Target 22.0 not reachable from node 770.0
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                | 797/1000 [1:06:09<14:18,  4.23s/it]WARNING:root:Target 481.0 not reachable from node 319.0
# WARNING:root:Target 481.0 not reachable from node 319.0
# WARNING:root:Target 481.0 not reachable from node 319.0
# WARNING:root:Target 481.0 not reachable from node 319.0
# WARNING:root:Target 481.0 not reachable from node 319.0
# WARNING:root:Target 481.0 not reachable from node 319.0
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                              | 811/1000 [1:07:01<15:27,  4.91s/it]WARNING:root:Target 772.0 not reachable from node 293.0
# WARNING:root:Target 772.0 not reachable from node 293.0
# WARNING:root:Target 772.0 not reachable from node 293.0
# WARNING:root:Target 772.0 not reachable from node 293.0
# WARNING:root:Target 772.0 not reachable from node 293.0
# WARNING:root:Target 772.0 not reachable from node 293.0
#  84%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 836/1000 [1:08:36<13:41,  5.01s/it]WARNING:root:Target 1051.0 not reachable from node 204.0
# WARNING:root:Target 1051.0 not reachable from node 204.0
# WARNING:root:Target 1051.0 not reachable from node 204.0
# WARNING:root:Target 1051.0 not reachable from node 204.0
# WARNING:root:Target 1051.0 not reachable from node 204.0
# WARNING:root:Target 1051.0 not reachable from node 204.0
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                         | 842/1000 [1:08:56<08:25,  3.20s/it]WARNING:root:Target 480.0 not reachable from node 250.0
# WARNING:root:Target 480.0 not reachable from node 250.0
# WARNING:root:Target 480.0 not reachable from node 250.0
# WARNING:root:Target 480.0 not reachable from node 250.0
# WARNING:root:Target 480.0 not reachable from node 250.0
# WARNING:root:Target 480.0 not reachable from node 250.0
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                    | 871/1000 [1:10:36<08:54,  4.15s/it]WARNING:root:Target 756.0 not reachable from node 349.0
# WARNING:root:Target 756.0 not reachable from node 349.0
# WARNING:root:Target 756.0 not reachable from node 349.0
# WARNING:root:Target 756.0 not reachable from node 349.0
# WARNING:root:Target 756.0 not reachable from node 349.0
# WARNING:root:Target 756.0 not reachable from node 349.0
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 876/1000 [1:11:04<11:56,  5.78s/it]WARNING:root:Target 320.0 not reachable from node 760.0
# WARNING:root:Target 320.0 not reachable from node 760.0
# WARNING:root:Target 320.0 not reachable from node 760.0
# WARNING:root:Target 320.0 not reachable from node 760.0
# WARNING:root:Target 320.0 not reachable from node 760.0
# WARNING:root:Target 320.0 not reachable from node 760.0
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                   | 878/1000 [1:11:06<07:22,  3.63s/it]WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
# WARNING:root:Target 85.0 not reachable from node 773.0
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 891/1000 [1:11:44<05:42,  3.14s/it]WARNING:root:Target 145.0 not reachable from node 771.0
# WARNING:root:Target 145.0 not reachable from node 771.0
# WARNING:root:Target 145.0 not reachable from node 771.0
# WARNING:root:Target 145.0 not reachable from node 771.0
# WARNING:root:Target 145.0 not reachable from node 771.0
# WARNING:root:Target 145.0 not reachable from node 771.0
#  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 927/1000 [1:13:53<05:37,  4.63s/it]WARNING:root:Target 762.0 not reachable from node 294.0
# WARNING:root:Target 762.0 not reachable from node 294.0
# WARNING:root:Target 762.0 not reachable from node 294.0
# WARNING:root:Target 762.0 not reachable from node 294.0
# WARNING:root:Target 762.0 not reachable from node 294.0
# WARNING:root:Target 762.0 not reachable from node 294.0
#  93%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎          | 934/1000 [1:14:20<04:02,  3.68s/it]WARNING:root:Target 1054.0 not reachable from node 77.0
# WARNING:root:Target 1054.0 not reachable from node 77.0
# WARNING:root:Target 1054.0 not reachable from node 77.0
# WARNING:root:Target 1054.0 not reachable from node 77.0
# WARNING:root:Target 1054.0 not reachable from node 77.0
# WARNING:root:Target 1054.0 not reachable from node 77.0
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉         | 944/1000 [1:14:51<02:26,  2.62s/it]WARNING:root:Target 775.0 not reachable from node 379.0
# WARNING:root:Target 775.0 not reachable from node 379.0
# WARNING:root:Target 775.0 not reachable from node 379.0
# WARNING:root:Target 775.0 not reachable from node 379.0
# WARNING:root:Target 775.0 not reachable from node 379.0
# WARNING:root:Target 775.0 not reachable from node 379.0
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 974/1000 [1:16:43<01:06,  2.56s/it]WARNING:root:Target 770.0 not reachable from node 456.0
# WARNING:root:Target 770.0 not reachable from node 456.0
# WARNING:root:Target 770.0 not reachable from node 456.0
# WARNING:root:Target 770.0 not reachable from node 456.0
# WARNING:root:Target 770.0 not reachable from node 456.0
# WARNING:root:Target 770.0 not reachable from node 456.0
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 989/1000 [1:17:27<00:30,  2.77s/it]WARNING:root:Target 1330.0 not reachable from node 773.0
# WARNING:root:Target 1330.0 not reachable from node 773.0
# WARNING:root:Target 1330.0 not reachable from node 773.0
# WARNING:root:Target 1330.0 not reachable from node 773.0
# WARNING:root:Target 1330.0 not reachable from node 773.0
# WARNING:root:Target 1330.0 not reachable from node 773.0
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 994/1000 [1:17:38<00:16,  2.71s/it]WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# WARNING:root:Target 466.0 not reachable from node 285.0
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [1:18:01<00:00,  4.68s/it]

# %% [markdown]
# # Results

# %%
for algorithm in algorithms:
    print(algorithm, np.mean(duration[algorithm]), np.std(duration[algorithm]))
# Out:
# tg 121.616 61.235990593767646
# tg_bst 113.743 58.31451749778952
# tg_cst 111.838 57.400346305575546
# tg_ttn_fc_ascending 103.643 53.693682598607445
# tg_ttn_fc_descending 103.432 54.243998525182484
# csa 744.626 432.2863866975226
# raptor 2195.996 1608.2302372434117
